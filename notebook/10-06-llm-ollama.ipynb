# %% [markdown]
# # Get up and running with large language models.
#
# https://ollama.com/
#
# Run Llama 3.1, Phi 3, Mistral, Gemma 2, and other models. Customize and create your own.
#
# ![image.png](attachment:image.png)
#
# Available for macOS, Linux, and Windows (preview)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Run ollama with  langchain_community

# %%
# 使用清华大学镜像快速安装Python包
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple -U ollama
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 3.3 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import ollama

# %%
ollama.chat(model='phi3:mini', messages=[{'role': 'user', 'content': 'Why is the sky blue?'}])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b02c7c07d971> in <module>
# ----> 1 ollama.chat(model='phi3:mini', messages=[{'role': 'user', 'content': 'Why is the sky blue?'}])
#
# /opt/anaconda3/lib/python3.8/site-packages/ollama/_client.py in chat(self, model, messages, tools, stream, format, options, keep_alive)
#     233         message['images'] = [_encode_image(image) for image in images]
#     234
# --> 235     return self._request_stream(
#     236       'POST',
#     237       '/api/chat',
#
# /opt/anaconda3/lib/python3.8/site-packages/ollama/_client.py in _request_stream(self, stream, *args, **kwargs)
#      96     **kwargs,
#      97   ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 98     return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#      99
#     100   @overload
#
# ...

# %%
# 使用清华大学镜像快速安装Python包
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple -U langchain_community
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple -U pydantic==2.7.0
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple -U pydantic_core==2.18.1
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.9/407.9 KB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.0.15 requires pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4, but you have pydantic 2.7.0 which is incompatible.
# ...

# %%
from langchain_community.llms import Ollama

# %%
llm = Ollama(model="phi3:mini")
llm.invoke("Why is the sky blue?")
# Out:
# "The color of the sky appears to be blue due to a phenomenon called Rayleigh scattering. Sunlight, which consists of various colors mixed together (much like light from an object), contains different wavelengths that interact with Earth'in atmosphere differently as sunlight passes through it. Blue and violet lights have shorter wavelengths compared to the other visible spectrum. The molecules in our air scatter these blue, so we see them coming towards us more frequently than any of the longer-wavelength colors like red or yellow (which is why during a golden hour after sunset when you can still feel light and warmth). However, since our eyes are less sensitive to violet light, it gets absorbed by ozone which also shields against damaging ultraviolet rays."

# %%
llm.invoke("What is socratic method?")
# Out:
# 'The Socratic Method, also known as the elenchus or maieutics after a Greek word for midwifery because it was believed to help individuals \'give birth\' to knowledge by questioning and dialogue. This pedagogical technique is attributed to the classical Greek philosopher Socrates who used this method of teaching, where students were encouraged to think critically through asking questions rather than being told facts outrightly or directly taught a subject matter. \n\nThe process begins with an individual posing questions which provoke critical thinking and illuminate ideas in dialogue form that is based on reasoned argumentation aiming at the discovery of understanding, truths about various subjects like ethics or justice among others through systematic question-andinan answer sequences where Socrates would guide his interlocutor to a self-discovery. \n\nHere\'s how it works: The teacher begins by asking questions that have clear answers – for instance "Do you know what virtue is?". 
# ...

# %% [markdown]
# ### Llama 3 : The most capable model
#
# Llama 3 represents a large improvement over Llama 2 and other openly available models:
#
# - Trained on a dataset seven times larger than Llama 2
# - Double the context length of 8K from Llama 2
# - Encodes language much more efficiently using a larger token vocabulary with 128K tokens
# - Less than 1⁄3 of the false “refusals” when compared to Llama 2

# %% [markdown]
# ### Llama 3
#
# now available to run using Ollama.
#
# To get started, Download Ollama and run Llama 3:
#
# > ollama run llama3

# %% [markdown]
# ![image.png](attachment:image.png)
