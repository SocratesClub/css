# %% [markdown]
# ---
# ---
# ### 计算社会科学简介
#
# # Introduction to Computational Social Science
#
# ---
# ---

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/computational-class/css/blob/master/notebooks/01.content.ipynb)

# %% [markdown]
# | [ 01.intro2css.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/01.intro2css.ipynb) |
# | ------------------------------------------------------------ |
# | [ 02.01-network-science-intro.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/02.01-network-science-intro.ipynb) |
# | [ 02.02-networkx.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/02.02-networkx.ipynb) |
# | [ 02.03-network-science-models.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/02.03-network-science-models.ipynb) |
# | [ 03.01.experiment.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/03.01.experiment.ipynb) |
# | [ 03.02.causality.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/03.02.causality.ipynb) |
# | [ 03.03.instrumental-variable.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/03.03.instrumental-variable.ipynb) |
# | [ 03.04.matching.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/03.04.matching.ipynb) |
# | [ 03.05.regression-discontinuity-designs.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/03.05.regression-discontinuity-designs.ipynb) |
# | [ 03.06.difference-in-difference.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/03.06.difference-in-difference.ipynb) |
# | [ 04.01.ABM.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/04.01.ABM.ipynb) |
# | [ 04.02.network_diffusion.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/04.02.network_diffusion.ipynb) |
# | [ 04.03-network-epidemics.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/04.03-network-epidemics.ipynb) |
# | [ 04.04.seir-hcd-model.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/04.04.seir-hcd-model.ipynb) |
# | [ 05.01-observing-behaviors.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/05.01-observing-behaviors.ipynb) |
# | [ 05.02-asking-questions.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/05.02-asking-questions.ipynb) |
# | [ 06.01-What-Is-Machine-Learning.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.01-What-Is-Machine-Learning.ipynb) |
# | [ 06.02-machine-learning-with-sklearn.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.02-machine-learning-with-sklearn.ipynb) |
# | [ 06.03-Hyperparameters-and-Model-Validation.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.03-Hyperparameters-and-Model-Validation.ipynb) |
# | [ 06.04-Feature-Engineering.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.04-Feature-Engineering.ipynb) |
# | [ 06.05-Naive-Bayes.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.05-Naive-Bayes.ipynb) |
# | [ 06.06-Linear-Regression.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.06-Linear-Regression.ipynb) |
# | [ 06.07-Support-Vector-Machines.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.07-Support-Vector-Machines.ipynb) |
# | [ 06.08-Random-Forests.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/06.08-Random-Forests.ipynb) |
# | [ 07.01-neural-network-intro.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/07.01-neural-network-intro.ipynb) |
# | [ 07.02-hand-written-digits.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/07.02-hand-written-digits.ipynb) |
# | [ 07.03.CNN.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/07.03.CNN.ipynb) |
# | [ 07.04-RNN.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/07.04-RNN.ipynb) |
# | [ 08.01-text-mining.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/08.01-text-mining.ipynb) |
# | [ 08.02-sentiment-analysis-with-dict.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/08.02-sentiment-analysis-with-dict.ipynb) |
# | [ 08.03-sentiment-classifier.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/08.03-sentiment-classifier.ipynb) |
# | [ 08.03.emotion_dict.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/08.03.emotion_dict.ipynb) |
# | [ 08.04-topic-models-update.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/08.04-topic-models-update.ipynb) |
# | [ 08.05-topic-models-with-turicreate.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/08.05-topic-models-with-turicreate.ipynb) |
# | [ 09-word2vec.ipynb](https://nbviewer.jupyter.org/github/computational-class/css/blob/master/notebook/09-word2vec.ipynb) |

# %% [markdown]
# ![image.png](attachment:image.png)
