# %% [markdown]
# # TechX2022 - 计算社科 - HW2

# %% [markdown]
# ## 第一题 按chunk读取并分析数据
#
# - 下载ows-raw.txt (链接见作业页面)
# - 按照https://chengjun.github.io/mybook/06-data-cleaning-preprocessing.html 中介绍的按照chunk读取数据的方式读取数据
# - 以使用csv包为例：
# - 提示：from collections import defaultdict
#     - 提示：`day_user_dict = defaultdict(list)`
# - 对链接中代码的lines写for循环进行遍历，提取每一行的day和user
#     - `day_user_dict[day].append(user)`
# - 注意对for循环里的每一行写try except语句规避错误
# - 最后：
#
# ```
# for i in day_user_dict:
#     print(i,len(day_user_dict[i]),len(set(day_user_dict[i])))
# ```
#
#
# 注意：请命名一个为 file_path 的字符串，其内容为 ows-raw.csv 的路径。在之后导入文件的时候直接使用这个变量，方便我们批改。

# %%
file_path = '/Users/qitianhu/Desktop/CSS-HW/Day1/ows-raw.csv'

# %%
num_lines
# Out:
# 6602141

# %% [markdown]
# b. 打印出每天分别有几条tweets，几个 unique users. 提示：可以使用 csv package 的 csv.reader。需要对每一行字符串需要进行一些必要的替换和处理。同时，为了缓解内存压力，需要分批读取与处理（比如每次读取10万行），然后在存储并更新结果之后读取下一批。

# %%
# Out:
# 1 100000
# 1 200000
# 2 300000
# 2 400000
# 2 500000
# 3 600000
# 3 700000
# 4 800000
# 4 900000
# 4 1000000
# 5 1100000
# 5 1200000
# 5 1300000
# 6 1400000
# 6 1500000
# 7 1600000
# 7 1700000
# 7 1800000
# 8 1900000
# 8 2000000
# 9 2100000
# 9 2200000
# 9 2300000
# 10 2400000
# 10 2500000
# 10 2600000
# 11 2700000
# 11 2800000
# 12 2900000
# 12 3000000
# 12 3100000
# 13 3200000
# 13 3300000
# 13 3400000
# 14 3500000
# 14 3600000
# 15 3700000
# 15 3800000
# 15 3900000
# 16 4000000
# 16 4100000
# 17 4200000
# 17 4300000
# 17 4400000
# 18 4500000
# 18 4600000
# 18 4700000
# 19 4800000
# 19 4900000
# 20 5000000
# 20 5100000
# 20 5200000
# 21 5300000
# 21 5400000
# 22 5500000
# 22 5600000
# 22 5700000
# 23 5800000
# 23 5900000
# 23 6000000
# 24 6100000
# 24 6200000
# 25 6300000
# 25 6400000
# 25 6500000
# 26 6600000

# %%
# 打印答案
# Out:
# day, #tweets, #users
# 2011-10-06 49638 18487
# 2011-10-07 65238 23460
# 2011-10-08 65949 23243
# 2011-10-09 65097 22576
# 2011-10-10 78619 27499
# 2011-10-11 67596 22955
# 2011-10-12 67753 25535
# 2011-10-13 98954 39200
# 2011-10-14 148062 47666
# 2011-10-15 161802 48951
# 2011-10-16 165381 51602
# 2011-10-17 113628 41525
# 2011-10-18 103337 37394
# 2011-10-19 88874 34990
# 2011-10-20 73159 29254
# 2011-10-21 75256 27029
# 2011-10-22 70368 24213
# 2011-10-23 64808 22378
# 2011-10-24 64571 24268
# 2011-10-25 74641 27084
# 2011-10-26 141729 46424
# 2011-10-27 137172 43368
# 2011-10-28 87216 31215
# 2011-10-29 75741 25319
# 2011-10-30 77813 24979
# 2011-10-31 64256 25911
# 2011-11-01 62286 23962
# 2011-11-02 74554 26559
# 2011-11-03 92698 32405
# 2011-11-04 63529 24288
# 2011-11-05 65019 22710
# 2011-11-06 55511 21374
# 2011-11-07 52820 20244
# 2011-11-08 47453 18503
# 2011-11-09 46503 17997
# 2011-11-10 52664 19455
# 2011-11-11 48997 18746
# 2011-11-12 38189 13954
# ...

# %% [markdown]
# # 题目2 基于占领华尔街推特数据预测被警察逮捕人数 (选做，非必选)
#
# - 首先阅读：Mooijman, M., Hoover, J., Lin, Y. et al. Moralization in social networks and the emergence of violence during protests. Nat Hum Behav 2, 389–396 (2018). https://doi.org/10.1038/s41562-018-0353-0
# - 下载并读取OWS被捕人数数据 https://www.stpete4peace.org/occupyarrests 参考：https://chengjun.github.io/mybook/06-data-cleaning-preprocessing.html 需要了解的内容：大数据的读取、清洗、文本挖掘的基础、机器学习的基本使用、基于时间序列的机器学习的逻辑
# - 提取ows tweets数据中的arrest、cops、police、nypd等词每天出现的次数
# - 分析这些词语在每天的词频与每天实际被捕人数之间的关系
